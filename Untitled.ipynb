# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(implace=True)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'], axis = 1)
y= data['median_house_value']

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16591    -121.44     37.73                 7.0       8363.0          1314.0
# 5794     -118.23     34.15                19.0       2294.0           716.0
# 9099     -117.92     34.63                34.0         81.0            26.0
# 9429     -122.68     38.07                26.0       1445.0           244.0
# 19280    -122.72     38.42                26.0       3604.0           734.0
# ...          ...       ...                 ...          ...             ...
# 17765    -121.86     37.35                43.0       1536.0           371.0
# 9882     -121.79     36.68                22.0       6912.0          1513.0
# 19306    -122.77     38.33                32.0       2054.0           324.0
# 4454     -118.17     34.10                37.0        299.0            89.0
# 16172    -122.54     37.72                17.0       2975.0           968.0
#
#        population  households  median_income ocean_proximity  \
# 16591      3907.0      1068.0         5.3321          INLAND
# 5794       1686.0       680.0         3.0288       <1H OCEAN
# 9099         53.0        14.0         1.4091          INLAND
# 9429        510.0       207.0         5.6305      NEAR OCEAN
# 19280      2605.0       704.0         3.0969       <1H OCEAN
# ...           ...         ...            ...             ...
# 17765      1256.0       357.0         2.8000       <1H OCEAN
# 9882       3794.0      1455.0         3.0608       <1H OCEAN
# 19306       843.0       306.0         4.5875       <1H OCEAN
# 4454        318.0        92.0         1.3125       <1H OCEAN
# 16172      1453.0       828.0         3.5270      NEAR OCEAN
#
#        median_house_value
# 16591            208100.0
# 5794             258300.0
# 9099             137500.0
# 9429             430000.0
# 19280            143800.0
# ...                   ...
# 17765            153300.0
# 9882             168300.0
# 19306            290700.0
# 4454             145800.0
# 16172            318900.0
#
# [16512 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Select only numeric columns
numeric_data = train_data.select_dtypes(include=['number'])

# %%
# compute correlation and plot heatmap
plt.figure(figsize=(15,8))
sns.heatmap(numeric_data.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis =1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16591    -121.44     37.73                 7.0     9.031692        7.181592
# 5794     -118.23     34.15                19.0     7.738488        6.575076
# 9099     -117.92     34.63                34.0     4.406719        3.295837
# 9429     -122.68     38.07                26.0     7.276556        5.501258
# 19280    -122.72     38.42                26.0     8.190077        6.599870
# ...          ...       ...                 ...          ...             ...
# 17765    -121.86     37.35                43.0     7.337588        5.918894
# 9882     -121.79     36.68                22.0     8.841159        7.322510
# 19306    -122.77     38.33                32.0     7.628031        5.783825
# 4454     -118.17     34.10                37.0     5.703782        4.499810
# 16172    -122.54     37.72                17.0     7.998335        6.876265
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 16591    8.270781    6.974479         5.3321            208100.0      False
# 5794     7.430707    6.523562         3.0288            258300.0       True
# 9099     3.988984    2.708050         1.4091            137500.0      False
# 9429     6.236370    5.337538         5.6305            430000.0      False
# 19280    7.865572    6.558198         3.0969            143800.0       True
# ...           ...         ...            ...                 ...        ...
# 17765    7.136483    5.880533         2.8000            153300.0       True
# 9882     8.241440    7.283448         3.0608            168300.0       True
# 19306    6.738152    5.726848         4.5875            290700.0       True
# 4454     5.765191    4.532599         1.3125            145800.0       True
# 16172    7.282074    6.720220         3.5270            318900.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 16591    True   False     False       False
# 5794    False   False     False       False
# 9099     True   False     False       False
# 9429    False   False     False        True
# 19280   False   False     False       False
# ...       ...     ...       ...         ...
# 17765   False   False     False       False
# 9882    False   False     False       False
# 19306   False   False     False       False
# 4454    False   False     False       False
# 16172   False   False     False        True
#
# [16512 rows x 14 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16591    -121.44     37.73                 7.0     9.031692        7.181592
# 5794     -118.23     34.15                19.0     7.738488        6.575076
# 9099     -117.92     34.63                34.0     4.406719        3.295837
# 9429     -122.68     38.07                26.0     7.276556        5.501258
# 19280    -122.72     38.42                26.0     8.190077        6.599870
# ...          ...       ...                 ...          ...             ...
# 17765    -121.86     37.35                43.0     7.337588        5.918894
# 9882     -121.79     36.68                22.0     8.841159        7.322510
# 19306    -122.77     38.33                32.0     7.628031        5.783825
# 4454     -118.17     34.10                37.0     5.703782        4.499810
# 16172    -122.54     37.72                17.0     7.998335        6.876265
#
#        population  households  median_income ocean_proximity  \
# 16591    8.270781    6.974479         5.3321          INLAND
# 5794     7.430707    6.523562         3.0288       <1H OCEAN
# 9099     3.988984    2.708050         1.4091          INLAND
# 9429     6.236370    5.337538         5.6305      NEAR OCEAN
# 19280    7.865572    6.558198         3.0969       <1H OCEAN
# ...           ...         ...            ...             ...
# 17765    7.136483    5.880533         2.8000       <1H OCEAN
# 9882     8.241440    7.283448         3.0608       <1H OCEAN
# 19306    6.738152    5.726848         4.5875       <1H OCEAN
# 4454     5.765191    4.532599         1.3125       <1H OCEAN
# 16172    7.282074    6.720220         3.5270      NEAR OCEAN
#
#        median_house_value
# 16591            208100.0
# 5794             258300.0
# 9099             137500.0
# 9429             430000.0
# 19280            143800.0
# ...                   ...
# 17765            153300.0
# 9882             168300.0
# 19306            290700.0
# 4454             145800.0
# 16172            318900.0
#
# [16512 rows x 10 columns]

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data= train_data, hue="median_house_value", palette = "coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data['total_bedrooms']/ train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(numeric_data.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
import pandas as pd

# One-hot encode categorical features
x_train = pd.get_dummies(train_data.drop(['median_house_value'], axis=1))
y_train = train_data['median_house_value']

# Impute missing values
imputer = SimpleImputer(strategy="mean")
x_train_imputed = imputer.fit_transform(x_train)

# Create and train the Linear Regression model
reg = LinearRegression()
reg.fit(x_train_imputed, y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

# Log transformation of specific columns to reduce skewness
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# One-hot encode the 'ocean_proximity' column and drop the original column
test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# Create new ratio-based features
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
from sklearn.impute import SimpleImputer

# Impute missing values in x_test
imputer = SimpleImputer(strategy="mean")
x_test_imputed = imputer.fit_transform(x_test)

# Now you can calculate the score
score = reg.score(x_test_imputed, y_test)
print("Model score:", score)
# Out:
# Model score: -5.9726790198948665

# %%
# Drop rows with NaN values
x_test_dropped = x_test.dropna()
y_test_dropped = y_test[x_test_dropped.index]  # Match y_test with the remaining x_test rows

# Calculate the score
score = reg.score(x_test_dropped, y_test_dropped)
print("Model score:", score)
# Out:
# Model score: -5.974761038542207
# c:\Users\LENOVO\Videos\Data Analytics\.venv\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
